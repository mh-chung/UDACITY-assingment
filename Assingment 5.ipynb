# %%
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'term', 'anarchism', 'originated', 'term', 'of', 'originated', 'as']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.934824
# Nearest to years: wollstonecraft, required, attends, analyzer, geminate, subpixel, toughness, kitab,
# Nearest to system: phyla, amendment, ashram, minions, armour, eulogy, snapshots, fathom,
# Nearest to during: sps, rainforest, kryptonian, marital, kosi, headstock, nanoscale, teletext,
# Nearest to united: transitioned, schirra, house, tetrahedra, latvians, sinclair, boroughs, solvable,
# Nearest to has: furor, elohim, officiate, raiding, iconostasis, prudence, perry, adar,
# Nearest to b: sarabande, sullivan, psalm, cia, ferrous, acr, activism, krebs,
# Nearest to which: coursework, thanks, highlander, subroutines, intern, schwenkfeld, glibc, hill,
# Nearest to about: withholding, chaparral, sacked, magnitudes, negro, locomotive, unrounded, albuquerque,
# Nearest to the: traditional, pared, dom, meal, cantos, detail, supersymmetric, labyrinth,
# Nearest to s: iterated, calvin, alienating, salient, kurz, rc, ganz, fyodorovna,
# Nearest to only: plumes, subtropical, stewards, confession, hated, kimberley, panipat, risking,
# Nearest to had: lange, australia, okinawan, pals, vivant, grasping, actinides, stride,
# Nearest to states: rallying, nicolay, wiccan, lai, atkinson, berkowitz, conveyed, zz,
# Nearest to are: gmc, throw, bronx, prisma, patience, expediency, horta, harder,
# Nearest to by: jaffa, welding, richest, wrote, hessen, tasmania, leftmost, jh,
# Nearest to were: mame, decrypted, intolerant, incentives, orcus, inscriptions, jerk, cheap,
# Average loss at step 2000: 4.370951
# Average loss at step 4000: 3.867874
# Average loss at step 6000: 3.788220
# Average loss at step 8000: 3.690778
# Average loss at step 10000: 3.615387
# Nearest to years: wollstonecraft, analyzer, twain, geminate, nigger, messages, sculptural, os,
# Nearest to system: phyla, amendment, armour, wake, earthman, proven, cubs, taken,
# Nearest to during: by, in, sps, bottlenecks, first, of, nanoscale, suffragette,
# Nearest to united: micrometer, tasting, sinclair, schirra, cooker, transitioned, house, solvable,
# Nearest to has: had, have, is, was, bastien, urine, soi, choreography,
# Nearest to b: krebs, sullivan, psalm, sleeves, d, decker, bashing, cia,
# Nearest to which: this, that, it, also, and, dedicates, rhythmically, haddo,
# Nearest to about: locomotive, origine, seymour, magnitudes, whose, chaparral, nomads, turbocharged,
# Nearest to the: his, a, this, its, their, an, each, kan,
# Nearest to s: his, and, resort, ganz, yogurt, cryonics, letterboxed, julius,
# Nearest to only: panipat, secured, concurrency, slithy, contemptuous, hated, stewards, nobita,
# Nearest to had: have, has, vivant, was, beanstalk, cutting, would, agreements,
# Nearest to states: rallying, expounded, tabled, atkinson, marriageable, callahan, sociologists, anasazi,
# Nearest to are: were, is, have, was, be, sums, overthrown, sandbox,
# Nearest to by: was, during, with, greedy, as, in, been, engravings,
# Nearest to were: are, was, have, is, exponentiation, cameron, and, storks,
# Average loss at step 12000: 3.605053
# Average loss at step 14000: 3.572673
# Average loss at step 16000: 3.409258
# Average loss at step 18000: 3.460004
# Average loss at step 20000: 3.540087
# Nearest to years: days, twain, messages, wollstonecraft, dendritic, sculptural, os, regrets,
# Nearest to system: cubs, phyla, earthman, wake, vested, proven, lager, infallibility,
# Nearest to during: in, by, at, after, bottlenecks, upon, sps, elbaradei,
# Nearest to united: house, tasting, micrometer, cooker, transitioned, suspicions, schirra, sinclair,
# Nearest to has: had, have, was, is, choreography, bolan, patented, optimizing,
# Nearest to b: d, krebs, accrued, overstated, nsfnet, hiker, cp, megali,
# Nearest to which: this, that, also, it, but, electroshock, who, punk,
# Nearest to about: origine, locomotive, nomads, seymour, morph, graphite, recede, turbocharged,
# Nearest to the: its, his, their, any, mayo, a, dazzle, an,
# Nearest to s: sacha, ganz, det, pen, herat, joel, cryonics, dans,
# Nearest to only: panipat, contemptuous, you, but, secured, it, concurrency, shakyamuni,
# Nearest to had: has, have, was, were, tintin, jealously, having, vivant,
# Nearest to states: rallying, expounded, sociologists, conservatorio, aol, belize, anasazi, atkinson,
# Nearest to are: were, is, have, exist, was, progressed, include, be,
# Nearest to by: be, were, against, with, during, was, for, in,
# Nearest to were: are, was, have, had, while, be, by, is,
# Average loss at step 22000: 3.504778
# Average loss at step 24000: 3.493135
# Average loss at step 26000: 3.478134
# Average loss at step 28000: 3.477202
# Average loss at step 30000: 3.506165
# Nearest to years: days, year, messages, twain, sculptural, months, analyzer, regrets,
# Nearest to system: cubs, systems, binyamin, spectrum, vested, angra, phyla, officially,
# Nearest to during: in, after, at, throughout, before, by, guderian, disciples,
# Nearest to united: tasting, house, micrometer, transitioned, cooker, suspicions, schirra, doolittle,
# Nearest to has: had, have, is, was, choreography, bastien, conspirator, pacheco,
# Nearest to b: d, cp, decker, accrued, deleuze, yell, krebs, bashing,
# Nearest to which: this, that, but, it, where, also, cryptology, scary,
# Nearest to about: origine, besides, nomads, morph, locomotive, depths, recede, magnitudes,
# Nearest to the: their, its, his, some, a, dazzle, any, this,
# Nearest to s: resort, joel, his, sesotho, its, vashem, ganz, sacha,
# Nearest to only: contemptuous, panipat, secured, shakyamuni, it, geosynchronous, hastened, fashions,
# Nearest to had: has, have, was, were, tintin, became, having, never,
# Nearest to states: rallying, expounded, state, sociologists, belize, kingdom, kuznetsova, ideas,
# Nearest to are: were, have, is, include, tropical, exist, toolkit, shriver,
# Nearest to by: was, during, against, brig, under, with, as, nikaya,
# Nearest to were: are, was, have, had, while, been, be, all,
# Average loss at step 32000: 3.503034
# Average loss at step 34000: 3.500224
# Average loss at step 36000: 3.456411
# Average loss at step 38000: 3.303509
# Average loss at step 40000: 3.431250
# Nearest to years: days, months, times, year, hundred, runs, twain, sculptural,
# Nearest to system: systems, cubs, vested, protest, lager, spectrum, fantagraphics, binyamin,
# Nearest to during: after, at, in, disciples, throughout, bai, before, elbaradei,
# Nearest to united: tasting, house, transitioned, micrometer, cooker, suspicions, fistful, following,
# Nearest to has: had, have, was, is, having, bastien, urine, patented,
# Nearest to b: d, UNK, cp, f, aeacus, leland, snp, decker,
# Nearest to which: that, this, there, often, it, but, also, who,
# Nearest to about: besides, aer, nomads, origine, renting, morph, veritas, noma,
# Nearest to the: their, its, a, any, his, this, another, each,
# Nearest to s: passos, sesotho, his, totalitarian, resort, and, koichi, emanate,
# Nearest to only: panipat, contemptuous, oceans, gradient, cathode, it, stewards, hatchet,
# Nearest to had: has, have, was, were, been, having, tintin, would,
# Nearest to states: kingdom, rallying, state, countries, belize, sociologists, ism, representatives,
# Nearest to are: were, have, is, include, while, although, including, but,
# Nearest to by: mutagenic, with, pavia, be, malenkov, for, elasticity, greedy,
# Nearest to were: are, have, was, had, while, been, be, became,
# Average loss at step 42000: 3.427823
# Average loss at step 44000: 3.458285
# Average loss at step 46000: 3.452798
# Average loss at step 48000: 3.358728
# Average loss at step 50000: 3.383691
# Nearest to years: days, months, times, year, hundred, people, sculptural, period,
# Nearest to system: systems, cubs, spectrum, vested, binyamin, lager, nodules, fantagraphics,
# Nearest to during: after, throughout, when, in, at, disciples, but, elbaradei,
# Nearest to united: tasting, house, transitioned, micrometer, fistful, cooker, fredric, suspicions,
# Nearest to has: had, have, was, is, having, bastien, contains, conspirator,
# Nearest to b: d, f, c, leland, pickups, cmi, snp, ld,
# Nearest to which: that, this, often, also, who, usually, these, what,
# Nearest to about: besides, renting, hon, origine, approximately, nomads, chronos, morph,
# Nearest to the: its, their, this, a, winged, some, wapping, his,
# Nearest to s: growling, elton, his, janet, popper, browning, sesotho, resort,
# Nearest to only: fashions, always, contemptuous, cathode, hatchet, guoyu, chromic, typically,
# Nearest to had: has, have, was, were, having, fiercely, pacheco, tintin,
# Nearest to states: kingdom, rallying, state, belize, herakles, recreationally, countries, conservatorio,
# Nearest to are: were, is, have, include, be, these, although, was,
# Nearest to by: was, brig, elasticity, after, under, during, be, from,
# Nearest to were: are, have, was, had, be, julmust, those, been,
# Average loss at step 52000: 3.440600
# Average loss at step 54000: 3.425870
# Average loss at step 56000: 3.437338
# Average loss at step 58000: 3.393060
# Average loss at step 60000: 3.391241
# Nearest to years: days, months, times, weeks, year, hundred, hours, decades,
# Nearest to system: systems, cubs, beforehand, spectrum, fantagraphics, binyamin, pinchcliffe, planet,
# Nearest to during: after, before, throughout, in, following, when, disciples, at,
# Nearest to united: tasting, transitioned, house, cooker, fistful, micrometer, fredric, doolittle,
# Nearest to has: had, have, is, was, having, bastien, conspirator, contains,
# Nearest to b: d, c, f, r, snp, pi, p, cabin,
# Nearest to which: that, this, what, however, there, it, these, who,
# Nearest to about: besides, dukakis, approximately, over, origine, on, aer, chronos,
# Nearest to the: its, their, a, his, this, each, some, these,
# Nearest to s: sacha, resentful, resort, oppositions, loser, jagiello, deuterocanonical, loving,
# Nearest to only: always, hatchet, typically, first, fashions, cathode, problem, contemptuous,
# Nearest to had: has, have, was, were, became, having, tintin, would,
# Nearest to states: kingdom, countries, nations, rallying, groups, ism, governments, state,
# Nearest to are: were, is, have, including, these, those, other, toolkit,
# Nearest to by: with, brig, greedy, elasticity, through, sill, under, pious,
# Nearest to were: are, was, have, while, had, been, although, including,
# Average loss at step 62000: 3.241668
# Average loss at step 64000: 3.255133
# Average loss at step 66000: 3.402680
# Average loss at step 68000: 3.399507
# Average loss at step 70000: 3.361329
# Nearest to years: days, months, weeks, times, year, decades, hours, hundred,
# Nearest to system: systems, spectrum, perspective, cubs, invokes, spectacular, beforehand, fantagraphics,
# Nearest to during: after, throughout, before, following, until, in, at, disciples,
# Nearest to united: transitioned, tasting, fredric, nation, fistful, doolittle, following, meteorologists,
# Nearest to has: had, have, was, is, bastien, since, having, pentameter,
# Nearest to b: d, f, p, r, c, x, ld, snp,
# Nearest to which: that, this, but, also, what, and, however, these,
# Nearest to about: besides, over, approximately, what, regarding, aer, eyelids, dukakis,
# Nearest to the: its, their, a, each, this, any, these, your,
# Nearest to s: depatie, whose, isbn, sacha, elton, gear, avatars, kronos,
# Nearest to only: always, best, still, until, cathode, chromic, gst, typically,
# Nearest to had: has, have, was, were, became, tintin, continued, having,
# Nearest to states: kingdom, countries, nations, rallying, state, nr, ism, belize,
# Nearest to are: were, have, is, include, while, including, although, these,
# Nearest to by: through, with, speculative, greedy, longing, in, directly, snowmen,
# Nearest to were: are, was, have, had, been, while, be, julmust,
# Average loss at step 72000: 3.373910
# Average loss at step 74000: 3.350916
# Average loss at step 76000: 3.316474
# Average loss at step 78000: 3.355657
# Average loss at step 80000: 3.380762
# Nearest to years: days, months, times, weeks, year, decades, minutes, hours,
# Nearest to system: systems, spectrum, fantagraphics, cubs, binyamin, pinchcliffe, beforehand, invokes,
# Nearest to during: after, throughout, before, in, when, until, following, despite,
# Nearest to united: nation, transitioned, tasting, fredric, same, micrometer, meteorologists, fistful,
# Nearest to has: had, have, is, was, having, since, bastien, dortmund,
# Nearest to b: d, c, ld, f, snp, sqrt, cp, elegance,
# Nearest to which: that, this, usually, also, actually, what, where, but,
# Nearest to about: approximately, besides, over, leszek, dukakis, regarding, aer, hon,
# Nearest to the: its, this, each, his, their, encamped, your, a,
# Nearest to s: isbn, elton, sesotho, oppositions, towel, browning, disclosures, dtmf,
# Nearest to only: until, always, first, best, inch, chromic, freely, conti,
# Nearest to had: have, has, were, was, began, became, having, tintin,
# Nearest to states: kingdom, nations, countries, state, rallying, belize, governments, us,
# Nearest to are: were, have, include, although, is, these, including, while,
# Nearest to by: elasticity, malenkov, vices, steamships, with, pavia, speculative, intensify,
# Nearest to were: are, was, had, have, been, although, julmust, those,
# Average loss at step 82000: 3.406473
# Average loss at step 84000: 3.411429
# Average loss at step 86000: 3.389425
# Average loss at step 88000: 3.354663
# Average loss at step 90000: 3.363411
# Nearest to years: days, months, weeks, decades, year, minutes, hours, times,
# Nearest to system: systems, spectrum, pinchcliffe, boxer, zoroastrian, binyamin, cubs, situation,
# Nearest to during: after, throughout, in, before, until, when, despite, following,
# Nearest to united: nation, transitioned, fredric, tasting, following, joins, same, meteorologists,
# Nearest to has: had, have, is, was, having, since, makes, conspirator,
# Nearest to b: d, c, f, ld, cp, r, z, cabin,
# Nearest to which: that, this, also, what, usually, often, these, actually,
# Nearest to about: besides, approximately, over, dukakis, regarding, aer, leszek, andechs,
# Nearest to the: its, their, each, his, your, a, this, trauma,
# Nearest to s: whose, his, sesotho, mae, vs, resort, pneumoniae, oppositions,
# Nearest to only: chromic, reals, gaye, always, fashions, freely, either, best,
# Nearest to had: have, has, was, were, having, continued, began, tintin,
# Nearest to states: kingdom, nations, state, us, rallying, countries, belize, urbanized,
# Nearest to are: were, is, have, include, these, although, those, randi,
# Nearest to by: through, under, propped, lep, against, using, greedy, elasticity,
# Nearest to were: are, had, while, have, was, although, julmust, those,
# Average loss at step 92000: 3.399907
# Average loss at step 94000: 3.254238
# Average loss at step 96000: 3.362907
# Average loss at step 98000: 3.248386
# Average loss at step 100000: 3.354576
# Nearest to years: days, months, weeks, decades, year, hours, times, minutes,
# Nearest to system: systems, pinchcliffe, spectrum, technology, hizballah, program, zoroastrian, device,
# Nearest to during: after, throughout, in, before, at, until, following, when,
# Nearest to united: nation, fredric, transitioned, following, same, senate, cooker, tasting,
# Nearest to has: had, have, is, was, having, since, karst, contains,
# Nearest to b: d, decker, abstracts, mcc, cp, affirming, exceptionally, sean,
# Nearest to which: that, this, usually, what, these, actually, also, it,
# Nearest to about: approximately, besides, over, dukakis, regarding, aer, on, hon,
# Nearest to the: your, their, his, its, a, our, some, her,
# Nearest to s: whose, his, the, isbn, elton, koichi, popper, teased,
# Nearest to only: mariah, still, fashions, always, chromic, probably, inch, reals,
# Nearest to had: has, have, was, were, could, would, having, is,
# Nearest to states: kingdom, nations, us, rallying, countries, state, belize, representatives,
# Nearest to are: were, include, have, although, is, exist, toolkit, these,
# Nearest to by: through, using, under, propped, when, during, without, brig,
# Nearest to were: are, was, had, have, these, those, although, while,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
data_index = 0

# skip-gram dataset generation function
def generate_cbow_batch(batch_size, skip_window):
  """
  
  Parameters
  ----------
  skips_window: int : How many words to consider left and right.
  
  """
  global data_index
#   assert batch_size % num_skips == 0
#   assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)

  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
#   buffer = []
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  
  for i in range(batch_size):
    batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
    labels[i] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
    
  return batch, labels

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  # note the different input dimensions for the CBOW model
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  # note the sum over the context embeddings for the CBOW model
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  embed = tf.reduce_sum(embed, 1)

  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, train_labels, embed,
                               num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_cbow_batch(
      batch_size, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From c:\users\minhee chung\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\util\tf_should_use.py:170: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 7.384683
# Nearest to had: normed, dominions, insufficiency, honor, dendritic, petr, gale, transitioned,
# Nearest to s: chunks, discouraging, vincendeau, headland, nate, sustainability, yarns, kickapoo,
# Nearest to first: norris, lucretius, poisson, daredevil, dusty, nanda, depatie, dg,
# Nearest to may: margrethe, gottfried, freeman, businessweek, nnhilde, pseudorandom, locates, iqs,
# Nearest to or: hormonal, involving, styne, germs, refractive, sip, isa, misconduct,
# Nearest to over: doj, claus, pao, fueled, slaves, omnipotence, stitches, isolation,
# Nearest to as: nazareth, federations, aspartame, jdf, erasing, closing, principle, battlefront,
# Nearest to system: columbanus, tattoos, ctesiphon, valencia, hungarian, mon, kaddish, variation,
# Nearest to to: immanuel, detection, voronin, harnack, engage, actuarial, almost, staggered,
# Nearest to when: distributes, burns, diy, hawkins, mercedes, mya, arouse, hgp,
# Nearest to world: tei, squandered, smokers, contractions, elmo, taraki, ingots, salvador,
# Nearest to and: abyss, spinners, enos, romita, salam, flirted, impasse, unsigned,
# Nearest to will: mais, heuristic, erewhon, eccentricity, tetrahedra, valves, dumfries, constitutive,
# Nearest to be: length, respiration, discounts, icc, hydroxyproline, leiber, paleontologists, universitet,
# Nearest to that: jumper, rheumatoid, parsing, glucose, serena, echoes, sweetener, christadelphians,
# Nearest to while: banff, tease, mesocricetus, locust, differentiate, decoration, acquis, excellence,
# Average loss at step 2000: 4.097899
# Average loss at step 4000: 3.555984
# Average loss at step 6000: 3.386877
# Average loss at step 8000: 3.242386
# Average loss at step 10000: 3.175576
# Nearest to had: has, have, was, were, having, slithy, lifes, apologia,
# Nearest to s: demonolatry, spearheaded, isbn, allyn, materialized, dispensed, disadvantaged, ystok,
# Nearest to first: last, final, tsuba, mates, automaton, reuben, second, during,
# Nearest to may: can, would, could, will, should, must, might, officiated,
# Nearest to or: and, than, hermetical, destroyers, ganga, represents, ial, shuffle,
# Nearest to over: slaves, gnat, same, pao, ehr, attendants, jaguars, strand,
# Nearest to as: rooke, kolingba, managers, gerardus, astrodome, marceau, wiseman, humorously,
# Nearest to system: tattoos, variation, kaddish, khuzestan, racine, complicates, columbanus, valencia,
# Nearest to to: could, can, would, domitia, nugget, teletype, will, kimberly,
# Nearest to when: where, kabila, theorised, if, ethnology, year, deference, financial,
# Nearest to world: seats, gulf, sundance, squandered, taraki, niro, mankind, second,
# Nearest to and: or, but, conformations, kambojas, plumb, lighting, obelix, s,
# Nearest to will: would, can, may, could, cannot, mellaart, should, komodoensis,
# Nearest to be: have, been, were, was, thermodynamically, ribbon, orthopedic, ramesh,
# Nearest to that: which, this, gehrig, however, laziness, it, palmyra, tert,
# Nearest to while: locust, however, decoration, tunisia, stryker, dunn, unjust, electorate,
# Average loss at step 12000: 3.199392
# Average loss at step 14000: 3.151096
# Average loss at step 16000: 3.178477
# Average loss at step 18000: 3.123028
# Average loss at step 20000: 2.990262
# Nearest to had: has, have, was, having, were, pours, patel, intends,
# Nearest to s: jfk, his, knox, starbucks, ne, demonolatry, isbn, kickapoo,
# Nearest to first: last, second, next, final, baritone, mates, reuben, same,
# Nearest to may: can, will, would, could, must, should, might, cannot,
# Nearest to or: and, than, et, oilseed, grateful, compensates, sravaka, catastrophic,
# Nearest to over: attendants, strand, collections, kneel, pstn, pao, miranda, labeling,
# Nearest to as: rooke, marceau, labors, constructivist, kulak, tatian, yak, scare,
# Nearest to system: systems, vojvodina, khuzestan, deadpan, khanna, descent, maximian, rucker,
# Nearest to to: cyc, nugget, could, comoros, would, multiplier, onetime, vague,
# Nearest to when: if, where, while, after, before, castilian, though, querying,
# Nearest to world: gulf, taraki, averages, seats, children, monomer, randomization, sundance,
# Nearest to and: or, but, incompatibilities, weathered, aldosterone, bend, pt, including,
# Nearest to will: would, can, may, could, should, must, cannot, might,
# Nearest to be: have, is, been, were, thermodynamically, ribbon, become, being,
# Nearest to that: which, this, however, what, gehrig, illustrations, but, turf,
# Nearest to while: when, although, however, but, stances, gaylord, intestinal, through,
# Average loss at step 22000: 3.070990
# Average loss at step 24000: 3.030758
# Average loss at step 26000: 3.002182
# Average loss at step 28000: 3.023376
# Average loss at step 30000: 3.003159
# Nearest to had: has, have, having, was, were, intends, patel, stanislaw,
# Nearest to s: activist, starbucks, and, deliriants, plumes, demonolatry, incorruptible, brugha,
# Nearest to first: last, second, next, final, same, tsuba, reuben, vectorborne,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to or: and, bray, than, nanking, but, parsecs, battuta, akkad,
# Nearest to over: attendants, into, through, off, across, pao, out, about,
# Nearest to as: rooke, emanated, when, spartan, after, fubar, using, millisecond,
# Nearest to system: systems, khanna, bronze, process, maximian, sforza, rucker, beaverbrook,
# Nearest to to: must, can, would, could, will, may, domitia, should,
# Nearest to when: if, before, although, where, while, after, though, because,
# Nearest to world: cryptologia, promises, gulf, joshua, u, monomer, cofactor, consonantal,
# Nearest to and: or, but, including, shuffle, shuster, pt, although, grossman,
# Nearest to will: would, can, may, could, must, should, might, cannot,
# Nearest to be: been, being, thermodynamically, lead, is, was, have, become,
# Nearest to that: which, what, this, however, where, nina, generally, tert,
# Nearest to while: although, when, however, before, after, though, including, but,
# Average loss at step 32000: 2.829283
# Average loss at step 34000: 2.949318
# Average loss at step 36000: 2.943419
# Average loss at step 38000: 2.942921
# Average loss at step 40000: 2.929617
# Nearest to had: has, have, having, was, were, patel, intends, stanislaw,
# Nearest to s: isbn, zhuhai, knox, retaliated, snapper, whose, hieroglyph, deianira,
# Nearest to first: last, second, next, final, same, third, experimentally, seventh,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to or: and, while, bray, although, parsecs, but, roper, goodfellas,
# Nearest to over: attendants, through, further, tokusatsu, about, fellini, concerning, alicante,
# Nearest to as: before, langston, when, ovation, principally, hao, fubar, scarcely,
# Nearest to system: systems, process, khanna, pierrot, technique, program, bronze, maximian,
# Nearest to to: nugget, would, will, can, should, might, cyc, could,
# Nearest to when: before, after, if, while, where, though, although, for,
# Nearest to world: cryptologia, promises, gulf, u, nation, certified, country, novello,
# Nearest to and: or, grossman, including, but, while, incompatibilities, than, lamprey,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to be: been, have, become, lead, being, is, were, was,
# Nearest to that: which, however, what, where, tert, witten, nina, myriad,
# Nearest to while: although, when, or, after, before, during, but, however,
# Average loss at step 42000: 2.949308
# Average loss at step 44000: 2.958931
# Average loss at step 46000: 2.908093
# Average loss at step 48000: 2.873479
# Average loss at step 50000: 2.848875
# Nearest to had: has, have, having, was, were, since, stanislaw, intends,
# Nearest to s: snapper, isbn, witted, knox, lennon, his, cumming, estonia,
# Nearest to first: last, second, next, final, same, third, experimentally, previous,
# Nearest to may: can, could, will, would, should, must, might, cannot,
# Nearest to or: and, while, than, through, although, though, goodfellas, treble,
# Nearest to over: off, through, attendants, out, further, across, around, fellini,
# Nearest to as: ovation, astrodome, like, constructivist, dignitaries, emanated, rooke, dore,
# Nearest to system: systems, process, technique, bronze, unit, rida, concourse, maximian,
# Nearest to to: could, should, nugget, decedent, will, dingo, electrophilic, mordred,
# Nearest to when: if, while, before, after, where, though, because, although,
# Nearest to world: promises, u, gulf, nation, cryptologia, joshua, grounds, season,
# Nearest to and: or, but, while, including, bosniak, than, damping, homeostatic,
# Nearest to will: would, can, could, may, must, should, might, cannot,
# Nearest to be: have, been, being, is, thermodynamically, become, are, get,
# Nearest to that: which, however, what, this, where, gabor, nationalities, costas,
# Nearest to while: when, although, after, before, though, if, are, and,
# Average loss at step 52000: 2.887684
# Average loss at step 54000: 2.864026
# Average loss at step 56000: 2.862799
# Average loss at step 58000: 2.748139
# Average loss at step 60000: 2.828195
# Nearest to had: has, have, was, having, stanislaw, utilizes, were, never,
# Nearest to s: upsilon, isbn, knox, whose, jt, retaliated, hbp, ystok,
# Nearest to first: last, second, next, final, third, seventh, experimentally, previous,
# Nearest to may: can, could, should, would, will, must, might, cannot,
# Nearest to or: and, than, though, medalist, bray, while, branagh, showered,
# Nearest to over: attendants, concerning, through, across, bei, between, off, around,
# Nearest to as: rooke, inscription, raphaelite, aho, pond, magee, constructivist, wiseman,
# Nearest to system: systems, process, technique, bronze, unit, situation, symbol, concourse,
# Nearest to to: will, would, should, might, could, must, indulgent, okeh,
# Nearest to when: if, before, after, while, where, though, during, because,
# Nearest to world: u, europe, promises, nation, gulf, joshua, resolutions, grounds,
# Nearest to and: or, but, although, including, genetical, while, loves, however,
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to be: been, become, have, get, being, is, were, lead,
# Nearest to that: which, however, what, krueger, how, tert, where, stephenson,
# Nearest to while: although, when, though, before, however, after, began, including,
# Average loss at step 62000: 2.833334
# Average loss at step 64000: 2.779073
# Average loss at step 66000: 2.762968
# Average loss at step 68000: 2.710916
# Average loss at step 70000: 2.789102
# Nearest to had: has, have, having, was, were, never, stanislaw, utilizes,
# Nearest to s: isbn, his, whose, knox, castrated, upsilon, cowper, activist,
# Nearest to first: last, second, next, third, final, seventh, fifth, previous,
# Nearest to may: can, should, will, could, must, would, might, cannot,
# Nearest to or: and, than, sul, noisy, bray, et, gila, simons,
# Nearest to over: attendants, across, further, off, through, bei, singhasari, concerning,
# Nearest to as: janis, spartan, wiseman, maghreb, ovation, when, kolingba, palermo,
# Nearest to system: systems, process, collisions, team, beaverbrook, rucker, lycos, symbol,
# Nearest to to: would, will, should, could, nugget, can, must, madly,
# Nearest to when: if, before, after, while, where, though, because, although,
# Nearest to world: u, promises, gulf, cryptologia, heroes, civilization, nation, joshua,
# Nearest to and: or, but, while, fright, bosniak, grossman, including, evan,
# Nearest to will: would, can, could, must, should, may, cannot, might,
# Nearest to be: been, have, become, is, being, mean, get, thermodynamically,
# Nearest to that: which, what, however, but, where, cassino, tert, unearthed,
# Nearest to while: although, when, though, after, before, however, began, including,
# Average loss at step 72000: 2.797385
# Average loss at step 74000: 2.641846
# Average loss at step 76000: 2.801334
# Average loss at step 78000: 2.827859
# Average loss at step 80000: 2.778774
# Nearest to had: has, have, having, was, were, stanislaw, intends, carangi,
# Nearest to s: isbn, whose, discouraging, activist, castrated, retaliated, reindeer, cumming,
# Nearest to first: last, next, second, third, final, fourth, same, best,
# Nearest to may: could, can, might, should, would, will, must, cannot,
# Nearest to or: and, though, than, bray, called, fac, semitone, teil,
# Nearest to over: across, off, attendants, through, around, about, showa, zier,
# Nearest to as: aho, yak, ovation, when, like, constructivist, before, spartan,
# Nearest to system: systems, process, hominy, dmc, situation, davies, team, technique,
# Nearest to to: opiates, should, nugget, will, kimberly, elwood, cycorp, madly,
# Nearest to when: if, before, while, after, though, where, although, during,
# Nearest to world: u, gulf, cryptologia, heroes, europe, civilization, season, ghana,
# Nearest to and: or, including, but, grossman, homeostatic, however, bosniak, prophase,
# Nearest to will: would, could, can, should, must, might, may, cannot,
# Nearest to be: become, been, get, produce, was, have, being, thermodynamically,
# Nearest to that: which, what, however, this, cassino, gehrig, witten, reflectance,
# Nearest to while: although, when, though, after, before, including, however, began,
# Average loss at step 82000: 2.666730
# Average loss at step 84000: 2.770079
# Average loss at step 86000: 2.738260
# Average loss at step 88000: 2.754610
# Average loss at step 90000: 2.735013
# Nearest to had: has, have, were, was, having, intends, utilizes, subsequently,
# Nearest to s: isbn, whose, activist, dispensed, knox, ystok, his, plumes,
# Nearest to first: last, next, second, final, third, earliest, previous, fourth,
# Nearest to may: can, might, should, could, would, must, will, cannot,
# Nearest to or: and, although, than, though, diddy, fac, parsecs, marais,
# Nearest to over: off, across, about, around, attendants, concerning, showa, through,
# Nearest to as: including, engel, spartan, like, after, prevailing, palermo, raphaelite,
# Nearest to system: systems, process, pierrot, davies, hominy, symbol, situation, unit,
# Nearest to to: would, might, should, could, nugget, cannot, will, towards,
# Nearest to when: if, though, before, after, although, while, where, because,
# Nearest to world: u, europe, country, gulf, civilization, cryptologia, isa, ghana,
# Nearest to and: or, including, but, bosniak, although, grossman, whilst, siddhartha,
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to be: become, been, being, have, get, thermodynamically, remain, lead,
# Nearest to that: which, what, however, where, tert, but, this, gehrig,
# Nearest to while: although, though, when, before, after, despite, during, sampa,
# Average loss at step 92000: 2.677109
# Average loss at step 94000: 2.719888
# Average loss at step 96000: 2.702611
# Average loss at step 98000: 2.363803
# Average loss at step 100000: 2.402822
# Nearest to had: has, have, was, having, intends, were, is, carangi,
# Nearest to s: whose, isbn, kickapoo, knox, castrated, american, upsilon, ystok,
# Nearest to first: last, next, second, third, final, fourth, earliest, fifth,
# Nearest to may: might, should, could, would, must, can, will, cannot,
# Nearest to or: and, than, though, yearwood, et, eugen, mills, parsecs,
# Nearest to over: off, across, attendants, around, out, concerning, aqueduct, tokusatsu,
# Nearest to as: constructivist, rooke, after, palermo, raphaelite, aho, nor, jn,
# Nearest to system: systems, process, unit, filament, cycladic, district, pierrot, symbol,
# Nearest to to: would, should, might, must, shall, will, cannot, could,
# Nearest to when: if, before, after, while, though, where, although, because,
# Nearest to world: u, rsted, gulf, cryptologia, heroes, extravagant, barthes, novel,
# Nearest to and: or, but, arana, including, however, cramer, grossman, genetical,
# Nearest to will: would, should, could, must, can, might, may, cannot,
# Nearest to be: become, been, being, have, were, get, thermodynamically, remain,
# Nearest to that: which, however, what, how, where, threw, krueger, whom,
# Nearest to while: although, though, when, before, began, after, but, kwajalein,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
